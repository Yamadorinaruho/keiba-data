# %%
import scraping
import importlib
importlib.reload(scraping)
from_ = "2024-01-01"
to_ = "2024-08-31"
scraping.scrape_kaisai_date_list(from_, to_)
# Out:
# /Users/yamadori/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#   0%|          | 0/8 [00:00<?, ?it/s]
# ['20240106',
#  '20240107',
#  '20240108',
#  '20240113',
#  '20240114',
#  '20240120',
#  '20240121',
#  '20240127',
#  '20240128',
#  '20240203',
#  '20240204',
#  '20240210',
#  '20240211',
#  '20240217',
#  '20240218',
#  '20240224',
#  '20240225',
#  '20240302',
#  '20240303',
#  '20240309',
#  '20240310',
#  '20240316',
#  '20240317',
#  '20240323',
#  '20240324',
#  '20240330',
#  '20240331',
#  '20240406',
#  '20240407',
#  '20240413',
#  '20240414',
#  '20240420',
#  '20240421',
#  '20240427',
#  '20240428',
#  '20240504',
#  '20240505',
#  '20240511',
#  '20240512',
#  '20240518',
#  '20240519',
#  '20240525',
#  '20240526',
#  '20240601',
#  '20240602',
# ...

# %%
scraping.scrape_race_id_list(from_,to_)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]
# ['202306010101',
#  '202306010102',
#  '202306010103',
#  '202306010104',
#  '202306010105',
#  '202306010106',
#  '202306010107',
#  '202306010108',
#  '202306010109',
#  '202306010110',
#  '202306010111',
#  '202306010112',
#  '202307010101',
#  '202307010102',
#  '202307010103',
#  '202307010104',
#  '202307010105',
#  '202307010106',
#  '202307010107',
#  '202307010108',
#  '202307010109',
#  '202307010110',
#  '202307010111',
#  '202307010112',
#  '202306010201',
#  '202306010202',
#  '202306010203',
#  '202306010204',
#  '202306010205',
#  '202306010206',
#  '202306010207',
#  '202306010208',
#  '202306010209',
#  '202306010210',
#  '202306010211',
#  '202306010212',
#  '202307010201',
#  '202307010202',
#  '202307010203',
#  '202307010204',
#  '202307010205',
#  '202307010206',
#  '202307010207',
#  '202307010208',
#  '202307010209',
#  '202307010210',
#  '202307010211',
#  '202307010212',
#  '202306010301',
#  '202306010302',
# ...

# %%
scraping.scrape_html_race(from_,to_)
# Out:
# race_id_list が見つからなかったので、scrape_race_id_list を呼び出します。
# ...
#   0%|          | 0/2363 [00:00<?, ?it/s]
# ../data/raw/html/race/202406010101.bin はすでに存在します。
# ../data/raw/html/race/202406010102.bin はすでに存在します。
# ../data/raw/html/race/202406010103.bin はすでに存在します。
# ../data/raw/html/race/202406010104.bin はすでに存在します。
# ../data/raw/html/race/202406010105.bin はすでに存在します。
# ../data/raw/html/race/202406010106.bin はすでに存在します。
# ../data/raw/html/race/202406010107.bin はすでに存在します。
# ../data/raw/html/race/202406010108.bin はすでに存在します。
# ../data/raw/html/race/202406010109.bin はすでに存在します。
# ../data/raw/html/race/202406010110.bin はすでに存在します。
# ../data/raw/html/race/202406010111.bin はすでに存在します。
# ../data/raw/html/race/202406010112.bin はすでに存在します。
# ../data/raw/html/race/202408010101.bin はすでに存在します。
# ../data/raw/html/race/202408010102.bin はすでに存在します。
# ../data/raw/html/race/202408010103.bin はすでに存在します。
# ../data/raw/html/race/202408010104.bin はすでに存在します。
# ../data/raw/html/race/202408010105.bin はすでに存在します。
# ...
