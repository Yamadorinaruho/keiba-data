# %% [markdown]
# ### 開催日とレースidの取得

# %%
import importlib
from pathlib import Path
import scraping
import create_raw
import df
importlib.reload(scraping)
importlib.reload(create_raw)
importlib.reload(df)
# Out:
# <module 'df' from '/Users/yamadori/keiba-data-1yr/common/src/df.py'>

# %%
scraping.scrape_html_race("2024-01-01", "2025-01-31")
# Out:
#   0%|          | 0/3694 [00:00<?, ?it/s]
# Skip: file exists (../data/html/race/202406010101.bin)
# Skip: file exists (../data/html/race/202406010102.bin)
# Skip: file exists (../data/html/race/202406010103.bin)
# Skip: file exists (../data/html/race/202406010104.bin)
# Skip: file exists (../data/html/race/202406010105.bin)
# Skip: file exists (../data/html/race/202406010106.bin)
# Skip: file exists (../data/html/race/202406010107.bin)
# Skip: file exists (../data/html/race/202406010108.bin)
# Skip: file exists (../data/html/race/202406010109.bin)
# Skip: file exists (../data/html/race/202406010110.bin)
# Skip: file exists (../data/html/race/202406010111.bin)
# Skip: file exists (../data/html/race/202406010112.bin)
# Skip: file exists (../data/html/race/202408010101.bin)
# Skip: file exists (../data/html/race/202408010102.bin)
# Skip: file exists (../data/html/race/202408010103.bin)
# Skip: file exists (../data/html/race/202408010104.bin)
# ...

# %%
create_raw.raw_race_csv()
# Out:
#   0%|          | 0/3694 [00:00<?, ?it/s]
# /Users/yamadori/keiba-data-1yr/common/src/create_raw.py:61: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(target_html)[0]  # 抽出したテーブルだけを変換
# /Users/yamadori/keiba-data-1yr/common/src/create_raw.py:61: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(target_html)[0]  # 抽出したテーブルだけを変換
# /Users/yamadori/keiba-data-1yr/common/src/create_raw.py:61: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(target_html)[0]  # 抽出したテーブルだけを変換
# ...

# %% [markdown]
# import importlib
# import scraping
# importlib.reload(scraping)
# scraping.scrape_race_html("2024-01-01", "2025-01-31")

# %%
create_raw.create_id_list()
# Out:
# ([2022105073,
#   2022105169,
#   2022105091,
#   2022104624,
#   2022102413,
#   2022100637,
#   2022106606,
#   2022105692,
#   2022107004,
#   2022103281,
#   2017105248,
#   2017104652,
#   2019105133,
#   2018106474,
#   2016104252,
#   2019101021,
#   2019103152,
#   2017104315,
#   2017100360,
#   2020104089,
#   2017106153,
#   2021100300,
#   2021100446,
#   2020102955,
#   2021106294,
#   2019103592,
#   2020106922,
#   2019102803,
#   2021105769,
#   2022104627,
#   2022103704,
#   2022100664,
#   2022102828,
#   2022104597,
#   2022106583,
#   2022102698,
#   2022100321,
#   2022106716,
#   2022103884,
#   2022100109,
#   2022106597,
#   2022100287,
#   2022103944,
#   2022100144,
#   2022101125,
#   2019105565,
#   2020103390,
#   2020110060,
#   2020101608,
#   2021105898,
#   2019103588,
#   2019105207,
#   2019100824,
#   2019104968,
#   2019105377,
#   2020102873,
#   2019105448,
#   2019103973,
#   2020103322,
#   2020101024,
#   2020105626,
#   2020103458,
# ...

# %%
scraping.scrape_html_horse()
# Out:
#   0%|          | 0/12291 [00:00<?, ?it/s]
# Skip: file exists (../data/html/horse/2022105073.bin)
# Skip: file exists (../data/html/horse/2022105169.bin)
# Skip: file exists (../data/html/horse/2022105091.bin)
# Skip: file exists (../data/html/horse/2022104624.bin)
# Skip: file exists (../data/html/horse/2022102413.bin)
# Skip: file exists (../data/html/horse/2022100637.bin)
# Skip: file exists (../data/html/horse/2022106606.bin)
# Skip: file exists (../data/html/horse/2022105692.bin)
# Skip: file exists (../data/html/horse/2022107004.bin)
# Skip: file exists (../data/html/horse/2022103281.bin)
# Skip: file exists (../data/html/horse/2017105248.bin)
# Skip: file exists (../data/html/horse/2017104652.bin)
# Skip: file exists (../data/html/horse/2019105133.bin)
# Skip: file exists (../data/html/horse/2018106474.bin)
# Skip: file exists (../data/html/horse/2016104252.bin)
# Skip: file exists (../data/html/horse/2019101021.bin)
# Skip: file exists (../data/html/horse/2019103152.bin)
# ...

# %%
df.df_race_csv()
# Out:
#             race_id    horse_id horse_name  jockey_id jockey_name  trainer_id  \
# 22889  202401010101  2022105762   ルージュアマリア       1188        永野猛蔵        1133
# 22887  202401010101  2022106999  ニシノクードクール       1169         武藤雅        1064
# 22888  202401010101  2022100639    ロードヴェルト       1170        横山武史        1113
# 22890  202401010101  2022100660   ロードヴァルカン       1199        角田大河        1186
# 22886  202401010101  2022105244    ポッドベイダー       1197        佐々木大        1192
# ...             ...         ...        ...        ...         ...         ...
# 12332  202510010212  2021110130     ドッビアーコ       1197        佐々木大        1146
# 12341  202510010212  2021105923     ミスサラワク       1212        柴田裕一        1056
# 12339  202510010212  2021106087   ピカレスクノベル       1181        秋山稔樹        1129
# 12342  202510010212  2020102961  リヤンドメテオール       1185        小沢大仁        1039
# 12340  202510010212  2019101233  アイファーファイト       1138        藤懸貴志        1046
#
# ...

# %%
create_raw.create_horse_raw_csv()
# Out:
#   0%|          | 0/8443 [00:00<?, ?it/s]
#                     日付    開催 天気    R           レース名  映像    頭数   枠番  馬番    オッズ  \
# horse_id
# 2022103997  2025/02/16  1小倉8  曇  5.0          3歳未勝利 NaN  14.0  8.0  13   94.6
# 2022103997  2025/02/02  1小倉4  晴  6.0          3歳未勝利 NaN  13.0  8.0  13   37.5
# 2022103997  2024/11/24  5東京8  晴  2.0          2歳未勝利 NaN  18.0  6.0  12  139.4
# 2022103997  2024/11/10  5東京4  曇  5.0           2歳新馬 NaN  10.0  5.0   5   83.4
# 2021104570  2025/01/04   名古屋  晴  8.0        凧あげ賞(B) NaN   9.0  7.0   8    1.2
# ...                ...   ... ..  ...            ...  ..   ...  ...  ..    ...
# 2020104640  2022/07/26    船橋  曇  3.0  リアトリスデビュー(2歳) NaN   6.0  3.0   3    8.4
# 2021104569  2024/09/21    佐賀  曇  5.0         3歳ー15組 NaN   7.0  6.0   6    8.6
# 2021104569  2024/09/07    佐賀  晴  7.0         3歳ー12組 NaN  10.0  5.0   5    2.8
# 2021104569  2024/01/07  1中山2  曇  3.0          3歳未勝利 NaN  15.0  5.0  10   84.2
# ...

# %%
df.df_race_csv()
# Out:
#             race_id    horse_id horse_name  jockey_id jockey_name  trainer_id  \
# 22889  202401010101  2022105762   ルージュアマリア       1188        永野猛蔵        1133
# 22887  202401010101  2022106999  ニシノクードクール       1169         武藤雅        1064
# 22888  202401010101  2022100639    ロードヴェルト       1170        横山武史        1113
# 22890  202401010101  2022100660   ロードヴァルカン       1199        角田大河        1186
# 22886  202401010101  2022105244    ポッドベイダー       1197        佐々木大        1192
# ...             ...         ...        ...        ...         ...         ...
# 12332  202510010212  2021110130     ドッビアーコ       1197        佐々木大        1146
# 12341  202510010212  2021105923     ミスサラワク       1212        柴田裕一        1056
# 12339  202510010212  2021106087   ピカレスクノベル       1181        秋山稔樹        1129
# 12342  202510010212  2020102961  リヤンドメテオール       1185        小沢大仁        1039
# 12340  202510010212  2019101233  アイファーファイト       1138        藤懸貴志        1046
#
# ...

# %%
df.df_horse_csv()
# Out:
#           horse_id       date  rank  prize  rank_diff  weather  race_type  \
# 0       2022103997 2025-02-16   6.0    0.0        0.3      2.0          1
# 1       2022103997 2025-02-02   8.0    0.0        1.5      1.0          1
# 2       2022103997 2024-11-24   9.0    0.0        1.6      1.0          1
# 3       2022103997 2024-11-10   4.0  110.0        1.2      2.0          1
# 4       2021104570 2025-01-04   1.0   60.0        0.0      1.0          0
# ...            ...        ...   ...    ...        ...      ...        ...
# 107348  2020104640 2022-07-26   2.0  108.0        0.2      2.0          0
# 107349  2021104569 2024-09-21   3.0    7.7        1.9      2.0          0
# 107350  2021104569 2024-09-07   5.0    3.4        0.7      1.0          0
# 107351  2021104569 2024-01-07  11.0    0.0        1.7      2.0          0
# 107352  2021104569 2023-11-05  12.0    0.0        5.3      2.0          0
#
#         course_len  ground_state  race_class  n_horses
# ...

# %%
create_raw.raw_race_info_csv()
# Out:
#   0%|          | 0/3694 [00:00<?, ?it/s]
#            race_id             title  \
# 0     202408060405              2歳新馬
# 1     202409020308    三木ホースランドJS(OP)
# 2     202402010807         3歳以上1勝クラス
# 3     202408070602             2歳未勝利
# 4     202408060411  第49回エリザベス女王杯(GI)
# ...            ...               ...
# 3689  202406040512         3歳以上1勝クラス
# 3690  202406040506              2歳新馬
# 3691  202410030707         3歳以上1勝クラス
# 3692  202409020311     ポラリスステークス(OP)
# 3693  202405010107         4歳以上1勝クラス
#
#                                                 info1  \
# 0                      [芝右2000m, 天候:晴, 芝:良, 発走:12:20]
# 1       [障芝3140m, 天候:晴, 芝:良, 発走:13:50, 過去の三木ホースランドJS]
# 2                    [ダ右1700m, 天候:曇, ダート:良, 発走:13:15]
# 3                    [ダ右1400m, 天候:晴, ダート:良, 発走:10:35]
# 4        [芝右外2200m, 天候:曇, 芝:良, 発走:15:40, 過去のエリザベス女王杯]
# ...                                               ...
# 3689                 [ダ右1200m, 天候:曇, ダート:良, 発走:16:30]
# ...

# %%
df.df_race_info_csv()
# Out:
#            race_id       date  race_type  around course_len  weather  \
# 0     202408060405 2024-11-10          1     0.0       2000        1
# 1     202409020308 2024-03-30          2     NaN       3140        1
# 2     202402010807 2024-06-30          0     0.0       1700        2
# 3     202408070602 2024-12-15          0     0.0       1400        1
# 4     202408060411 2024-11-10          1     0.0       2200        2
# ...            ...        ...        ...     ...        ...      ...
# 3689  202406040512 2024-09-16          0     0.0       1200        2
# 3690  202406040506 2024-09-16          1     0.0       1800        2
# 3691  202410030707 2024-07-20          1     0.0       2000        2
# 3692  202409020311 2024-03-30          0     0.0       1400        1
# 3693  202405010107 2024-01-27          0     1.0       1400        1
#
#       ground_state  race_class  place
# 0                0           0      8
# 1                0           5      9
# ...

# %%
create_raw.raw_race_return_csv()
# Out:
#   0%|          | 0/3694 [00:00<?, ?it/s]
# /Users/yamadori/keiba-data-1yr/common/src/create_raw.py:221: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pay_block.find_all('table')
# /Users/yamadori/keiba-data-1yr/common/src/create_raw.py:221: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pay_block.find_all('table')
# /Users/yamadori/keiba-data-1yr/common/src/create_raw.py:221: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pay_block.find_all('table')
# ...

# %%
df.df_race_return_csv()
# Out:
#        index bet_type  win_umaban  return
# 0          0       単勝        [10]     230
# 1          1       複勝        [10]     120
# 2          1       複勝         [5]     130
# 3          1       複勝         [1]     140
# 4          3       馬連     [5, 10]     460
# ...      ...      ...         ...     ...
# 40616  29330      ワイド     [2, 16]    2860
# 40617  29330      ワイド     [1, 16]    2920
# 40618  29331       馬単      [2, 1]    1480
# 40619  29332      三連複  [1, 2, 16]   12180
# 40620  29333      三連単  [2, 1, 16]   40460
#
# [40621 rows x 4 columns]
